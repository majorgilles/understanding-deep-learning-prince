# %% [markdown]
# # Chapter 14 — Unsupervised Learning: Study Guide
#
# > The official UDL repository does not currently provide a Chapter 14 notebook. This original starter notebook keeps every chapter independently followable.
#
# - [Chapter PDF](../chapter-14-unsupervised-learning.pdf)
# - [Chapter notes](../notes.md)
# - [GitHub issue #14](https://github.com/majorgilles/understanding-deep-learning-prince/issues/14)
# - [Course website](https://udlbook.github.io/udlbook/)
#
# ## Learning tasks
#
# 1. Build a comparison table for likelihood-based, implicit, and latent-variable generative models.
# 2. Define fidelity, diversity, and tractability, then explain where they can conflict.
# 3. Choose a real dataset and propose quantitative and qualitative evaluation criteria.
# 4. Record your conclusions in `../notes.md`; add experiments here as new cells.
